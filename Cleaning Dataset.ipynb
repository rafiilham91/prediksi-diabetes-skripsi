# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('dataset_diabetes_skripsi.csv')
df
# Out:
#           puskesmas     kelurahan  umur  jk  merokok  aktivitas_fisik  \
# 0     bogor selatan     Pamoyanan  48.0   0        0                0
# 1     bogor selatan     PAMOYANAN  75.0   0        0                0
# 2     bogor selatan     PAMOYANAN  67.0   0        0                1
# 3     bogor selatan   Ranggamekar  42.0   0        0                0
# 4     bogor selatan   Ranggamekar  45.0   0        0                0
# ...             ...           ...   ...  ..      ...              ...
# 2097   warung jambu  KEDUNGHALANG  66.0   1        0                0
# 2098   warung jambu  KEDUNGHALANG  75.0   1        0                0
# 2099   warung jambu  KEDUNGHALANG  47.0   1        0                0
# 2100   warung jambu      CIPARIGI  61.0   1        0                0
# 2101   warung jambu      CIPARIGI  55.0   0        0                0
#
#       konsumsi_alkohol  tekanan_darah    bmi  lingkar_perut  pemeriksaan_gula  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2102 entries, 0 to 2101
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   puskesmas         2102 non-null   object
#  1   kelurahan         2102 non-null   object
#  2   umur              2093 non-null   float64
#  3   jk                2102 non-null   int64
#  4   merokok           2102 non-null   int64
#  5   aktivitas_fisik   2102 non-null   int64
#  6   konsumsi_alkohol  2102 non-null   int64
#  7   tekanan_darah     2101 non-null   float64
#  8   bmi               2101 non-null   float64
#  9   lingkar_perut     2102 non-null   float64
#  10  pemeriksaan_gula  2102 non-null   int64
#  11  latitude          2102 non-null   float64
#  12  longitude         2102 non-null   float64
#  13  diagnosis         2102 non-null   int64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 230.0+ KB

# %%
df = df.drop(['longitude', 'latitude'], axis=1)

# %%
df.describe()
# Out:
#               umur           jk      merokok  aktivitas_fisik  \
# count  2093.000000  2102.000000  2102.000000      2102.000000
# mean     54.426183     0.499524     0.344910         0.500000
# std      13.315624     0.500119     0.475452         0.500119
# min      16.000000     0.000000     0.000000         0.000000
# 25%      47.000000     0.000000     0.000000         0.000000
# 50%      55.000000     0.000000     0.000000         0.500000
# 75%      63.000000     1.000000     1.000000         1.000000
# max     124.000000     1.000000     1.000000         1.000000
#
#        konsumsi_alkohol  tekanan_darah          bmi  lingkar_perut  \
# count            2102.0    2101.000000  2101.000000    2102.000000
# mean                0.0      81.259400    24.197830      85.197288
# std                 0.0      18.996361     5.410037      22.324543
# min                 0.0      31.000000     0.210000       0.000000
# 25%                 0.0      70.000000    21.440000      79.000000
# ...

# %%
nan_data = df[df.isna().any(axis=1)]
nan_data
# Out:
#         puskesmas    kelurahan  umur  jk  merokok  aktivitas_fisik  \
# 190   bogor timur  Sindangrasa   NaN   1        0                0
# 1054    bondongan      CIKARET  52.0   1        0                1
# 1364       cipaku      Genteng   NaN   1        0                1
# 1373       cipaku      Genteng   NaN   0        1                1
# 1377       cipaku      Genteng   NaN   1        0                1
# 1562       cipaku      Genteng   NaN   1        0                1
# 1571       cipaku      Genteng   NaN   0        1                1
# 1575       cipaku      Genteng   NaN   1        0                1
# 1586       cipaku    Rancamaya  27.0   1        0                0
# 1609       cipaku      Genteng   NaN   1        0                0
# 1617       cipaku      Genteng   NaN   1        0                0
#
#       konsumsi_alkohol  tekanan_darah    bmi  lingkar_perut  pemeriksaan_gula  \
# 190                  0           80.0  25.39           90.0               118
# ...

# %%
# Menghapus baris dengan data yang kosong
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# puskesmas           0
# kelurahan           0
# umur                0
# jk                  0
# merokok             0
# aktivitas_fisik     0
# konsumsi_alkohol    0
# tekanan_darah       0
# bmi                 0
# lingkar_perut       0
# pemeriksaan_gula    0
# diagnosis           0
# dtype: int64

# %%
# Merapikan nama kelurahan (huruf besar di awal setiap kata)
df['kelurahan'] = df['kelurahan'].str.title()

# %%
df['puskesmas'] = df['puskesmas'].str.title()
df

# %%
# Menyimpan dataset yang sudah dibersihkan ke file CSV baru
# df.to_csv('diabetes_skripsi.csv', index=False)
